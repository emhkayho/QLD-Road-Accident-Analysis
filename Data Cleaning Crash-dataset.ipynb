# %% [markdown]
# ### Crash Data-QueensLand Australia(Data Quality Check)

# %% [markdown]
# ##### Let us start by importing relevant libraries

# %%
#Importing Libraries and loading data sets
import pandas as pd
import numpy as np
import datetime as dt
import warnings
warnings.filterwarnings('ignore')
crash_locations = pd.read_csv('crash_data_queensland_1_crash_locations.csv')
road_casualties = pd.read_csv('crash_data_queensland_a_road_casualties.csv')
driver_involvement = pd.read_csv('crash_data_queensland_b_driver_involvement.csv')
use_helment = pd.read_csv('crash_data_queensland_c_restraint_helmet_use.csv')
vehicle_involvement = pd.read_csv('crash_data_queensland_d_vehicle_involvement.csv')
specific_factors = pd.read_csv('crash_data_queensland_e_alcohol_speed_fatigue_defect.csv')

# %% [markdown]
# we would be looking at the data individually to check the integrity, quality and completness of the data

# %% [markdown]
# Our Data Cleaning steps:
# Data cleaning is a crucial step in the data analysis process that involves identifying and correcting errors, inconsistencies, and missing values in a dataset. Here are some general steps we will follow when performing the data cleaning:
#
# 1.Identify the data quality issues: We start by exploring the data to identify any data quality issues, such as missing values, duplicates, incorrect data types, or inconsistent formatting.
#
# 2.Remove duplicates: If we find duplicate records in the dataset, we remove them to avoid overrepresentation of certain data points.
#
# 3.Handle missing values: We will Decide how to handle missing values, whether by imputing them with a reasonable estimate, deleting the entire record or column, or keeping them as missing values.
#
# 4.Standardize data format: We will Standardize the format of your data to ensure consistency, for example, by converting data to a common data type or unit of measurement.
#
# 5.Document data cleaning steps: Keep track of the steps we have taken during data cleaning, so that others can understand how we have processed the data and reproduce our results.
#
# By following these general steps(not in particular order), we can perform effective data cleaning that will help us get better insights from your data

# %% [markdown]
# ### 1.Getting an Understanding of the data

# %% [markdown]
# #### Having a look at available data

# %%
#let's look at all the columns
pd.set_option('display.max_columns',None)
crash_locations.head()
# Out:
#    Crash_Ref_Number        Crash_Severity  Crash_Year Crash_Month  \
# 0                 1       Hospitalisation        2001     January
# 1                 2  Property damage only        2001     January
# 2                 3          Minor injury        2001     January
# 3                 4  Property damage only        2001     January
# 4                 5  Property damage only        2001     January
#
#   Crash_Day_Of_Week  Crash_Hour Crash_Nature      Crash_Type  Crash_Longitude  \
# 0            Monday           6      Head-on   Multi-Vehicle       153.052207
# 1         Wednesday           9        Angle   Multi-Vehicle       153.064920
# 2          Thursday           8     Rear-end   Multi-Vehicle       153.058444
# 3            Sunday           8   Hit object  Single Vehicle       153.081083
# 4           Tuesday          16   Overturned  Single Vehicle         0.000009
#
#    Crash_Latitude  Crash_Street Crash_Street_Intersecting State_Road_Name  \
# ...

# %%
#Overview of data
crash_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367230 entries, 0 to 367229
# Data columns (total 52 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Crash_Ref_Number                 367230 non-null  int64
#  1   Crash_Severity                   367230 non-null  object
#  2   Crash_Year                       367230 non-null  int64
#  3   Crash_Month                      367230 non-null  object
#  4   Crash_Day_Of_Week                367230 non-null  object
#  5   Crash_Hour                       367230 non-null  int64
#  6   Crash_Nature                     367230 non-null  object
#  7   Crash_Type                       367230 non-null  object
#  8   Crash_Longitude                  367230 non-null  float64
#  9   Crash_Latitude                   367230 non-null  float64
#  10  Crash_Street                     367215 non-null  object
# ...

# %%
road_casualties.head()
# Out:
#    Crash_Year Crash_Police_Region  Casualty_Severity Casualty_AgeGroup  \
# 0        2006         North Coast  Medically treated          40 to 49
# 1        2006       South Eastern  Medically treated          40 to 49
# 2        2006            Southern  Medically treated           0 to 16
# 3        2007         North Coast  Medically treated          40 to 49
# 4        2007            Southern  Medically treated          17 to 24
#
#   Casualty_Gender Casualty_RoadUserType  Casualty_Count
# 0          Female                Driver              71
# 1            Male                Driver              54
# 2          Female            Pedestrian               7
# 3            Male             Passenger               6
# 4          Female                Driver              79

# %%
road_casualties.info()
#there are no null value in this table and the datatypes are correct
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32527 entries, 0 to 32526
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Crash_Year             32527 non-null  int64
#  1   Crash_Police_Region    32527 non-null  object
#  2   Casualty_Severity      32527 non-null  object
#  3   Casualty_AgeGroup      32527 non-null  object
#  4   Casualty_Gender        32527 non-null  object
#  5   Casualty_RoadUserType  32527 non-null  object
#  6   Casualty_Count         32527 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 1.7+ MB

# %%
driver_involvement.head()
# Out:
#    Crash_Year Crash_Police_Region Crash_Severity Involving_Male_Driver  \
# 0        2001            Brisbane          Fatal                    No
# 1        2001            Brisbane          Fatal                    No
# 2        2001            Brisbane          Fatal                    No
# 3        2001            Brisbane          Fatal                    No
# 4        2001            Brisbane          Fatal                    No
#
#   Involving_Female_Driver Involving_Young_Driver_16-24  \
# 0                      No                           No
# 1                     Yes                           No
# 2                     Yes                           No
# 3                     Yes                           No
# 4                     Yes                           No
#
#   Involving_Senior_Driver_60plus Involving_Provisional_Driver  \
# 0                             No                           No
# 1                             No                           No
# ...

# %%
driver_involvement.info()
#the data is complete with correct datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19896 entries, 0 to 19895
# Data columns (total 16 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Crash_Year                          19896 non-null  int64
#  1   Crash_Police_Region                 19896 non-null  object
#  2   Crash_Severity                      19896 non-null  object
#  3   Involving_Male_Driver               19896 non-null  object
#  4   Involving_Female_Driver             19896 non-null  object
#  5   Involving_Young_Driver_16-24        19896 non-null  object
#  6   Involving_Senior_Driver_60plus      19896 non-null  object
#  7   Involving_Provisional_Driver        19896 non-null  object
#  8   Involving_Overseas_Licensed_Driver  19896 non-null  object
#  9   Involving_Unlicensed_Driver         19896 non-null  object
#  10  Count_Crashes                       19896 non-null  int64
# ...

# %%
use_helment.head()
# Out:
#    Crash_Year Crash_PoliceRegion Casualty_Severity Casualty_AgeGroup  \
# 0        2001           Brisbane          Fatality           0 to 16
# 1        2001           Brisbane          Fatality          17 to 24
# 2        2001           Brisbane          Fatality          25 to 29
# 3        2001           Brisbane          Fatality          30 to 39
# 4        2001           Brisbane          Fatality          30 to 39
#
#   Casualty_Gender Casualty_Road_User_Type Casualty_Restraint_Helmet_Use  \
# 0          Female        Vehicle Occupant                    Restrained
# 1          Female        Vehicle Occupant                    Restrained
# 2          Female        Vehicle Occupant  Restraint Use Not determined
# 3          Female        Vehicle Occupant  Restraint Use Not determined
# 4          Female        Vehicle Occupant                  Unrestrained
#
#    Casualty_Count
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
use_helment.info()
#No null values in this dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36212 entries, 0 to 36211
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Crash_Year                     36212 non-null  int64
#  1   Crash_PoliceRegion             36212 non-null  object
#  2   Casualty_Severity              36212 non-null  object
#  3   Casualty_AgeGroup              36212 non-null  object
#  4   Casualty_Gender                36212 non-null  object
#  5   Casualty_Road_User_Type        36212 non-null  object
#  6   Casualty_Restraint_Helmet_Use  36212 non-null  object
#  7   Casualty_Count                 36212 non-null  int64
# dtypes: int64(2), object(6)
# memory usage: 2.2+ MB

# %%
vehicle_involvement.head()
# Out:
#    Crash_Year Crash_Police_Region Crash_Severity Involving_Motorcycle_Moped  \
# 0        2001            Brisbane          Fatal                         No
# 1        2001            Brisbane          Fatal                         No
# 2        2001            Brisbane          Fatal                         No
# 3        2001            Brisbane          Fatal                        Yes
# 4        2001            Brisbane          Fatal                        Yes
#
#   Involving_Truck Involving_Bus  Count_Crashes  Count_Casualty_Fatality  \
# 0              No            No             36                       38
# 1              No           Yes              1                        1
# 2             Yes            No              1                        1
# 3              No            No              5                        5
# 4             Yes            No              1                        1
#
#    Count_Casualty_Hospitalised  Count_Casualty_MedicallyTreated  \
# ...

# %%
vehicle_involvement.info()
#the dataset does not have missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3246 entries, 0 to 3245
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Crash_Year                       3246 non-null   int64
#  1   Crash_Police_Region              3246 non-null   object
#  2   Crash_Severity                   3246 non-null   object
#  3   Involving_Motorcycle_Moped       3246 non-null   object
#  4   Involving_Truck                  3246 non-null   object
#  5   Involving_Bus                    3246 non-null   object
#  6   Count_Crashes                    3246 non-null   int64
#  7   Count_Casualty_Fatality          3246 non-null   int64
#  8   Count_Casualty_Hospitalised      3246 non-null   int64
#  9   Count_Casualty_MedicallyTreated  3246 non-null   int64
#  10  Count_Casualty_MinorInjury       3246 non-null   int64
#  11  Count_Casualty_All               3246 non-null   int64
# ...

# %%
specific_factors.head()
# Out:
#    Crash_Year Crash_Police_Region Crash_Severity Involving_Drink_Driving  \
# 0        2001            Brisbane          Fatal                      No
# 1        2001            Brisbane          Fatal                      No
# 2        2001            Brisbane          Fatal                      No
# 3        2001            Brisbane          Fatal                     Yes
# 4        2001            Brisbane          Fatal                     Yes
#
#   Involving_Driver_Speed Involving_Fatigued_Driver  \
# 0                     No                        No
# 1                     No                        No
# 2                    Yes                        No
# 3                     No                        No
# 4                     No                        No
#
#   Involving_Defective_Vehicle  Count_Crashes  Count_Fatality  \
# 0                          No             25              25
# 1                         Yes              1               1
# ...

# %%
specific_factors.info()
#There are no mising values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4799 entries, 0 to 4798
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Crash_Year                   4799 non-null   int64
#  1   Crash_Police_Region          4799 non-null   object
#  2   Crash_Severity               4799 non-null   object
#  3   Involving_Drink_Driving      4799 non-null   object
#  4   Involving_Driver_Speed       4799 non-null   object
#  5   Involving_Fatigued_Driver    4799 non-null   object
#  6   Involving_Defective_Vehicle  4799 non-null   object
#  7   Count_Crashes                4799 non-null   int64
#  8   Count_Fatality               4799 non-null   int64
#  9   Count_Hospitalised           4799 non-null   int64
#  10  Count_Medically_Treated      4799 non-null   int64
#  11  Count_Minor_Injury           4799 non-null   int64
#  12  Count_All_Casualties         4799 non-null   int64
# ...

# %% [markdown]
# The crash_locations dataset is the only dataset with missing values. Going forward, we will be looking at filling some of the missing values and dropping some of the irrelevant columns

# %% [markdown]
# ### 2.1 Dealing with inconsistent formatting and Standardising our Datatype

# %%
crash_locations.head()
# Out:
#    Crash_Ref_Number        Crash_Severity  Crash_Year Crash_Month  \
# 0                 1       Hospitalisation        2001     January
# 1                 2  Property damage only        2001     January
# 2                 3          Minor injury        2001     January
# 3                 4  Property damage only        2001     January
# 4                 5  Property damage only        2001     January
#
#   Crash_Day_Of_Week  Crash_Hour Crash_Nature      Crash_Type  Crash_Longitude  \
# 0            Monday           6      Head-on   Multi-Vehicle       153.052207
# 1         Wednesday           9        Angle   Multi-Vehicle       153.064920
# 2          Thursday           8     Rear-end   Multi-Vehicle       153.058444
# 3            Sunday           8   Hit object  Single Vehicle       153.081083
# 4           Tuesday          16   Overturned  Single Vehicle         0.000009
#
#    Crash_Latitude  Crash_Street Crash_Street_Intersecting State_Road_Name  \
# ...

# %%
#making a copy of the data
crash_loc = crash_locations.copy()

# %%
crash_loc['Crash_Nature'].value_counts()
# Out:
# Angle                            109955
# Rear-end                          90408
# Hit object                        79770
# Overturned                        18653
# Sideswipe                         17322
# Hit pedestrian                    14545
# Hit parked vehicle                12492
# Fall from vehicle                 10038
# Head-on                            8860
# Hit animal                         3534
# Non-collision - miscellaneous       771
# Struck by external load             468
# Collision - miscellaneous           338
# Other                                57
# Struck by internal load              19
# Name: Crash_Nature, dtype: int64

# %%
crash_loc['Crash_Type'].value_counts()
# Out:
# Multi-Vehicle     226545
# Single Vehicle    120953
# Hit pedestrian     14545
# Other               5187
# Name: Crash_Type, dtype: int64

# %%
crash_loc['Loc_Police_Region'].value_counts()
# Out:
# Brisbane         109835
# North Coast       69779
# South Eastern     64541
# Southern          46122
# Central           33274
# Far Northern      22344
# Northern          20737
# Unknown             598
# Name: Loc_Police_Region, dtype: int64

# %%
crash_loc['Crash_DCA_Group_Description'].value_counts()
# Out:
# Rear-end                                    88150
# Intersection from adjacent approaches       53668
# Off carriageway on straight hit object      36033
# Opposing vehicles turning                   32780
# Other                                       29112
# Off carriageway on curve hit object         26519
# Vehicle leaving driveway                    14149
# Pedestrian                                  12868
# Head-on                                     12152
# Lane changes                                11709
# Out of control on straight                   7988
# Parallel lanes turning                       7896
# Hit parked vehicle                           7892
# Out of control on curve                      7716
# Off carriageway on straight                  6563
# Off carriageway on curve                     4197
# Hit animal                                   3410
# Overtaking same direction                    1956
# U-turn                                       1918
# ...

# %% [markdown]
# Here we show some of the counts for various of the data categories which are consistent, also all the data we would be looking at using from this dataset are also complete

# %%
road_cas = road_casualties.copy()

# %%
road_cas.head()
# Out:
#    Crash_Year Crash_Police_Region  Casualty_Severity Casualty_AgeGroup  \
# 0        2006         North Coast  Medically treated          40 to 49
# 1        2006       South Eastern  Medically treated          40 to 49
# 2        2006            Southern  Medically treated           0 to 16
# 3        2007         North Coast  Medically treated          40 to 49
# 4        2007            Southern  Medically treated          17 to 24
#
#   Casualty_Gender Casualty_RoadUserType  Casualty_Count
# 0          Female                Driver              71
# 1            Male                Driver              54
# 2          Female            Pedestrian               7
# 3            Male             Passenger               6
# 4          Female                Driver              79

# %%
road_cas['Crash_Police_Region'].value_counts()
# Out:
# Brisbane         5368
# North Coast      5295
# South Eastern    5093
# Southern         4436
# Central          4124
# Far Northern     4096
# Northern         3829
# Unknown           286
# Name: Crash_Police_Region, dtype: int64

# %%
road_cas['Casualty_Severity'].value_counts()
# Out:
# Hospitalised         10709
# Medically treated    10147
# Minor injury          8228
# Fatality              3443
# Name: Casualty_Severity, dtype: int64

# %%
road_cas['Casualty_AgeGroup'].value_counts()
#later we will drop the categories with unknown in this attribute
# Out:
# 17 to 24       4572
# 30 to 39       4419
# 40 to 49       4296
# 50 to 59       4040
# 25 to 29       3968
# 60 to 74       3691
# 0 to 16        3639
# 75 and over    2632
# Unknown        1270
# Name: Casualty_AgeGroup, dtype: int64

# %%
road_cas['Casualty_Gender'].value_counts()
#we would change the unknown here to Male since it is most common
# Out:
# Male       17948
# Female     13977
# Unknown      602
# Name: Casualty_Gender, dtype: int64

# %%
road_cas['Casualty_RoadUserType'].value_counts()
# Out:
# Passenger       8453
# Driver          8436
# Motorcyclist    5377
# Pedestrian      5372
# Bicyclist       4587
# Other            302
# Name: Casualty_RoadUserType, dtype: int64

# %%
#replacing values
road_cas['Casualty_Gender'] = road_cas['Casualty_Gender'].str.replace('Unknown','Male')
road_cas['Casualty_Gender'].value_counts()
# Out:
# Male      18550
# Female    13977
# Name: Casualty_Gender, dtype: int64

# %%
#removing Unknown from the Agegroup
road_cas= road_cas[road_cas['Casualty_AgeGroup'] != 'Unknown']

# %%
road_cas['Casualty_AgeGroup'].value_counts()
# Out:
# 17 to 24       4572
# 30 to 39       4419
# 40 to 49       4296
# 50 to 59       4040
# 25 to 29       3968
# 60 to 74       3691
# 0 to 16        3639
# 75 and over    2632
# Name: Casualty_AgeGroup, dtype: int64

# %%
driver_involvement
#we will not be using this data in our analysis since similar information is already on the road_casualities dataset
# Out:
#        Crash_Year Crash_Police_Region Crash_Severity Involving_Male_Driver  \
# 0            2001            Brisbane          Fatal                    No
# 1            2001            Brisbane          Fatal                    No
# 2            2001            Brisbane          Fatal                    No
# 3            2001            Brisbane          Fatal                    No
# 4            2001            Brisbane          Fatal                    No
# ...           ...                 ...            ...                   ...
# 19891        2021            Southern   Minor injury                   Yes
# 19892        2021            Southern   Minor injury                   Yes
# 19893        2021            Southern   Minor injury                   Yes
# 19894        2021            Southern   Minor injury                   Yes
# 19895        2021            Southern   Minor injury                   Yes
#
#       Involving_Female_Driver Involving_Young_Driver_16-24  \
# ...

# %%
use_helment
# Out:
#        Crash_Year Crash_PoliceRegion Casualty_Severity Casualty_AgeGroup  \
# 0            2001           Brisbane          Fatality           0 to 16
# 1            2001           Brisbane          Fatality          17 to 24
# 2            2001           Brisbane          Fatality          25 to 29
# 3            2001           Brisbane          Fatality          30 to 39
# 4            2001           Brisbane          Fatality          30 to 39
# ...           ...                ...               ...               ...
# 36207        2021           Southern      Minor injury          50 to 59
# 36208        2021           Southern      Minor injury          60 to 74
# 36209        2021           Southern      Minor injury          60 to 74
# 36210        2021           Southern      Minor injury       75 and over
# 36211        2021           Southern      Minor injury       75 and over
#
#       Casualty_Gender Casualty_Road_User_Type Casualty_Restraint_Helmet_Use  \
# ...

# %%
restraint = use_helment.copy()

# %%
restraint.head()
# Out:
#    Crash_Year Crash_PoliceRegion Casualty_Severity Casualty_AgeGroup  \
# 0        2001           Brisbane          Fatality           0 to 16
# 1        2001           Brisbane          Fatality          17 to 24
# 2        2001           Brisbane          Fatality          25 to 29
# 3        2001           Brisbane          Fatality          30 to 39
# 4        2001           Brisbane          Fatality          30 to 39
#
#   Casualty_Gender Casualty_Road_User_Type Casualty_Restraint_Helmet_Use  \
# 0          Female        Vehicle Occupant                    Restrained
# 1          Female        Vehicle Occupant                    Restrained
# 2          Female        Vehicle Occupant  Restraint Use Not determined
# 3          Female        Vehicle Occupant  Restraint Use Not determined
# 4          Female        Vehicle Occupant                  Unrestrained
#
#    Casualty_Count
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
restraint['Crash_PoliceRegion'].value_counts()
# Out:
# Brisbane         6248
# North Coast      6037
# South Eastern    5826
# Southern         4858
# Central          4485
# Far Northern     4386
# Northern         4081
# Unknown           291
# Name: Crash_PoliceRegion, dtype: int64

# %%
restraint['Casualty_Severity'].value_counts()
# Out:
# Hospitalised         12325
# Medically treated    11385
# Minor injury          9093
# Fatality              3409
# Name: Casualty_Severity, dtype: int64

# %%
restraint['Casualty_AgeGroup'].value_counts()
# Out:
# 17 to 24       5593
# 30 to 39       5200
# 40 to 49       4899
# 25 to 29       4505
# 50 to 59       4328
# 0 to 16        4316
# 60 to 74       3746
# 75 and over    2391
# Unknown        1234
# Name: Casualty_AgeGroup, dtype: int64

# %%
#removing Unknown from the Agegroup
restraint= restraint[restraint['Casualty_AgeGroup'] != 'Unknown']

# %%
restraint['Casualty_Gender'].value_counts()
# Out:
# Male       20865
# Female     13839
# Unknown      274
# Name: Casualty_Gender, dtype: int64

# %%
#replacing values
restraint['Casualty_Gender'] = restraint['Casualty_Gender'].str.replace('Unknown','Male')
restraint['Casualty_Gender'].value_counts()
# Out:
# Male      21139
# Female    13839
# Name: Casualty_Gender, dtype: int64

# %%
restraint['Casualty_Road_User_Type'].value_counts()
# Out:
# Vehicle Occupant    21558
# Motorcyclist         7130
# Bicyclist            6290
# Name: Casualty_Road_User_Type, dtype: int64

# %%
restraint['Casualty_Restraint_Helmet_Use'].value_counts()
# Out:
# Helmet Worn                     9090
# Restrained                      8443
# Restraint Use Not determined    7376
# Unrestrained                    4466
# Helmet Use Not determined       2440
# Helmet Not Worn                 1833
# Not applicable                  1330
# Name: Casualty_Restraint_Helmet_Use, dtype: int64

# %%
#looking at vehicle involvement
vehicle_invol = vehicle_involvement.copy()
vehicle_invol.head()
#we would not be using this dataset too since the crash location already has similar information
# Out:
#    Crash_Year Crash_Police_Region Crash_Severity Involving_Motorcycle_Moped  \
# 0        2001            Brisbane          Fatal                         No
# 1        2001            Brisbane          Fatal                         No
# 2        2001            Brisbane          Fatal                         No
# 3        2001            Brisbane          Fatal                        Yes
# 4        2001            Brisbane          Fatal                        Yes
#
#   Involving_Truck Involving_Bus  Count_Crashes  Count_Casualty_Fatality  \
# 0              No            No             36                       38
# 1              No           Yes              1                        1
# 2             Yes            No              1                        1
# 3              No            No              5                        5
# 4             Yes            No              1                        1
#
#    Count_Casualty_Hospitalised  Count_Casualty_MedicallyTreated  \
# ...

# %%
#looking at the factors dataset
factors = specific_factors.copy()
factors.head()
# Out:
#    Crash_Year Crash_Police_Region Crash_Severity Involving_Drink_Driving  \
# 0        2001            Brisbane          Fatal                      No
# 1        2001            Brisbane          Fatal                      No
# 2        2001            Brisbane          Fatal                      No
# 3        2001            Brisbane          Fatal                     Yes
# 4        2001            Brisbane          Fatal                     Yes
#
#   Involving_Driver_Speed Involving_Fatigued_Driver  \
# 0                     No                        No
# 1                     No                        No
# 2                    Yes                        No
# 3                     No                        No
# 4                     No                        No
#
#   Involving_Defective_Vehicle  Count_Crashes  Count_Fatality  \
# 0                          No             25              25
# 1                         Yes              1               1
# ...

# %%
#looking at categories
factors['Involving_Drink_Driving'].value_counts()
# Out:
# No     2931
# Yes    1868
# Name: Involving_Drink_Driving, dtype: int64

# %%
factors['Involving_Driver_Speed'].value_counts()
# Out:
# No     3077
# Yes    1722
# Name: Involving_Driver_Speed, dtype: int64

# %%
factors['Involving_Fatigued_Driver'].value_counts()
# Out:
# No     3702
# Yes    1097
# Name: Involving_Fatigued_Driver, dtype: int64

# %%
factors['Involving_Defective_Vehicle'].value_counts()
# Out:
# No     3671
# Yes    1128
# Name: Involving_Defective_Vehicle, dtype: int64

# %% [markdown]
# ### 2.2 Dealing with Missing Values and dropping columns

# %%
crash_loc.info()
#We see that the year,month and day of the week has the a wrongly assigned datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367230 entries, 0 to 367229
# Data columns (total 52 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Crash_Ref_Number                 367230 non-null  int64
#  1   Crash_Severity                   367230 non-null  object
#  2   Crash_Year                       367230 non-null  int64
#  3   Crash_Month                      367230 non-null  object
#  4   Crash_Day_Of_Week                367230 non-null  object
#  5   Crash_Hour                       367230 non-null  int64
#  6   Crash_Nature                     367230 non-null  object
#  7   Crash_Type                       367230 non-null  object
#  8   Crash_Longitude                  367230 non-null  float64
#  9   Crash_Latitude                   367230 non-null  float64
#  10  Crash_Street                     367215 non-null  object
# ...

# %% [markdown]
# we would be keeping the following columns:
#
# 1.Crash_ref_Number, 2.Crash_Severity, 3.Crash_Year, 4.Crash_Month, 5.Crash_Day_Of_Week, 6.Crash_Nature,
# 7.Crash_Type, 8.Loc_ABS_Remoteness, 9.Crash_Roadway_Feature, 10.Crash_Traffic_Control , 11.Crash_Speed_Limit
# 12.Loc_Police_Region, 13.Crash_Atmospheric_Condition, 14.Crash_Lighting_Condition, 15.Crash_DCA_Code, 16.Crash_DCA_Group_Description
# 17.Count_Casualty_Fatality, 18.Count_Casualty_Hospitalised, 19.Count_Casualty_MedicallyTreated, 20.Count_Casualty_MinorInjury,
# 21.Count_Casualty_Total, 22.Count_Unit_Car, 23.Count_Unit_Motorcycle_Moped, 24.Count_Unit_Truck, 25.Count_Unit_Bus,
# 26.Count_Unit_Bicycle, 28.Count_Unit_Pedestrian, 29.Count_Unit_Other

# %%
loc_crash = crash_loc[['Crash_Ref_Number','Crash_Severity', 'Crash_Year', 'Crash_Month','Crash_Day_Of_Week','Crash_Nature',
                       'Crash_Type','Loc_ABS_Remoteness','Crash_Roadway_Feature','Crash_Traffic_Control', 
                       'Crash_Speed_Limit','Loc_Police_Region','Crash_Atmospheric_Condition','Crash_Lighting_Condition', 
                       'Crash_DCA_Code','Crash_DCA_Group_Description','Count_Casualty_Fatality','Count_Casualty_Hospitalised', 
                       'Count_Casualty_MedicallyTreated','Count_Casualty_MinorInjury','Count_Casualty_Total', 
                       'Count_Unit_Car', 'Count_Unit_Motorcycle_Moped', 'Count_Unit_Truck', 'Count_Unit_Bus', 
                       'Count_Unit_Bicycle', 'Count_Unit_Pedestrian','Count_Unit_Other']].copy()

loc_crash
# Out:
#         Crash_Ref_Number        Crash_Severity  Crash_Year Crash_Month  \
# 0                      1       Hospitalisation        2001     January
# 1                      2  Property damage only        2001     January
# 2                      3          Minor injury        2001     January
# 3                      4  Property damage only        2001     January
# 4                      5  Property damage only        2001     January
# ...                  ...                   ...         ...         ...
# 367225            367226     Medical treatment        2018        July
# 367226            367227     Medical treatment        2018        July
# 367227            367228       Hospitalisation        2018        July
# 367228            367229     Medical treatment        2018        July
# 367229            367230     Medical treatment        2018        July
#
#        Crash_Day_Of_Week    Crash_Nature      Crash_Type Loc_ABS_Remoteness  \
# ...

# %%
loc_crash.isnull().sum()
#let us drop the nul values since they are not much
# Out:
# Crash_Ref_Number                    0
# Crash_Severity                      0
# Crash_Year                          0
# Crash_Month                         0
# Crash_Day_Of_Week                   0
# Crash_Nature                        0
# Crash_Type                          0
# Loc_ABS_Remoteness                  0
# Crash_Roadway_Feature               0
# Crash_Traffic_Control               0
# Crash_Speed_Limit                   3
# Loc_Police_Region                   0
# Crash_Atmospheric_Condition         0
# Crash_Lighting_Condition            0
# Crash_DCA_Code                     84
# Crash_DCA_Group_Description         0
# Count_Casualty_Fatality             0
# Count_Casualty_Hospitalised         0
# Count_Casualty_MedicallyTreated     0
# Count_Casualty_MinorInjury          0
# Count_Casualty_Total                0
# Count_Unit_Car                      0
# Count_Unit_Motorcycle_Moped         0
# Count_Unit_Truck                    0
# Count_Unit_Bus                      0
# ...

# %%
loc_crash.dropna(subset=['Crash_Speed_Limit','Crash_DCA_Code'],inplace =True)

# %%
road_cas.isnull().sum()
# Out:
# Crash_Year               0
# Crash_Police_Region      0
# Casualty_Severity        0
# Casualty_AgeGroup        0
# Casualty_Gender          0
# Casualty_RoadUserType    0
# Casualty_Count           0
# dtype: int64

# %%
restraint.isnull().sum()
# Out:
# Crash_Year                       0
# Crash_PoliceRegion               0
# Casualty_Severity                0
# Casualty_AgeGroup                0
# Casualty_Gender                  0
# Casualty_Road_User_Type          0
# Casualty_Restraint_Helmet_Use    0
# Casualty_Count                   0
# dtype: int64

# %%
factors.isnull().sum()
# Out:
# Crash_Year                     0
# Crash_Police_Region            0
# Crash_Severity                 0
# Involving_Drink_Driving        0
# Involving_Driver_Speed         0
# Involving_Fatigued_Driver      0
# Involving_Defective_Vehicle    0
# Count_Crashes                  0
# Count_Fatality                 0
# Count_Hospitalised             0
# Count_Medically_Treated        0
# Count_Minor_Injury             0
# Count_All_Casualties           0
# dtype: int64

# %% [markdown]
# Apart from the loc_crash dataset, the datasets we would be using in our analysis does not have missing values

# %% [markdown]
# ### 2.3 Dealing with duplicates

# %%
#checking for duplicates in loc_crash
duplicates_loc = loc_crash[loc_crash.duplicated()]
num_duplicates_loc = duplicates_loc.shape[0]
num_duplicates_loc
# Out:
# 0

# %%
#checking for duplicates in road_cas
duplicates_cas = road_cas[road_cas.duplicated()]
num_duplicates_cas = duplicates_cas.shape[0]
num_duplicates_cas
# Out:
# 5

# %%
#Since they are 5 duplicates in road casualties we drop them
road_cas.drop_duplicates(inplace = True)

# %%
#checking for duplicates in restraint
duplicates_res = restraint[restraint.duplicated()]
num_duplicates_res = duplicates_res.shape[0]
num_duplicates_res
# Out:
# 4

# %%
restraint.drop_duplicates(inplace = True)

# %%
#checking for duplicates in factors
duplicates_fac = factors[factors.duplicated()]
num_duplicates_fac = duplicates_fac.shape[0]
num_duplicates_fac
# Out:
# 0

# %%
loc_crash['Count_Unit_Motorcycle_Moped'].value_counts()
# Out:
# 0    334170
# 1     32323
# 2       612
# 3        29
# 4         6
# 5         3
# Name: Count_Unit_Motorcycle_Moped, dtype: int64

# %% [markdown]
# ### Conclusion

# %% [markdown]
# We have been able to sucessfully clean Dataset by removing NaN values, dealing with inconsistent datatypes and finally dropping columns. We can now move forward to extracting our clean data for the analysis.

# %%
loc_crash.to_csv("crash_locations.csv",index=False)
loc_crash.head()
# Out:
#    Crash_Ref_Number        Crash_Severity  Crash_Year Crash_Month  \
# 0                 1       Hospitalisation        2001     January
# 1                 2  Property damage only        2001     January
# 2                 3          Minor injury        2001     January
# 3                 4  Property damage only        2001     January
# 4                 5  Property damage only        2001     January
#
#   Crash_Day_Of_Week Crash_Nature      Crash_Type Loc_ABS_Remoteness  \
# 0            Monday      Head-on   Multi-Vehicle       Major Cities
# 1         Wednesday        Angle   Multi-Vehicle       Major Cities
# 2          Thursday     Rear-end   Multi-Vehicle       Major Cities
# 3            Sunday   Hit object  Single Vehicle       Major Cities
# 4           Tuesday   Overturned  Single Vehicle            Unknown
#
#        Crash_Roadway_Feature     Crash_Traffic_Control Crash_Speed_Limit  \
# 0         No Roadway Feature        No traffic control       0 - 50 km/h
# ...

# %%
road_cas.to_csv("road_casualties.csv",index=False)
road_cas.head()
# Out:
#    Crash_Year Crash_Police_Region  Casualty_Severity Casualty_AgeGroup  \
# 0        2006         North Coast  Medically treated          40 to 49
# 1        2006       South Eastern  Medically treated          40 to 49
# 2        2006            Southern  Medically treated           0 to 16
# 3        2007         North Coast  Medically treated          40 to 49
# 4        2007            Southern  Medically treated          17 to 24
#
#   Casualty_Gender Casualty_RoadUserType  Casualty_Count
# 0          Female                Driver              71
# 1            Male                Driver              54
# 2          Female            Pedestrian               7
# 3            Male             Passenger               6
# 4          Female                Driver              79

# %%
restraint.to_csv("restraint.csv",index=False)
restraint.head()
# Out:
#    Crash_Year Crash_PoliceRegion Casualty_Severity Casualty_AgeGroup  \
# 0        2001           Brisbane          Fatality           0 to 16
# 1        2001           Brisbane          Fatality          17 to 24
# 2        2001           Brisbane          Fatality          25 to 29
# 3        2001           Brisbane          Fatality          30 to 39
# 4        2001           Brisbane          Fatality          30 to 39
#
#   Casualty_Gender Casualty_Road_User_Type Casualty_Restraint_Helmet_Use  \
# 0          Female        Vehicle Occupant                    Restrained
# 1          Female        Vehicle Occupant                    Restrained
# 2          Female        Vehicle Occupant  Restraint Use Not determined
# 3          Female        Vehicle Occupant  Restraint Use Not determined
# 4          Female        Vehicle Occupant                  Unrestrained
#
#    Casualty_Count
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
factors.to_csv("factors.csv",index=False)
factors.head()
#end
# Out:
#    Crash_Year Crash_Police_Region Crash_Severity Involving_Drink_Driving  \
# 0        2001            Brisbane          Fatal                      No
# 1        2001            Brisbane          Fatal                      No
# 2        2001            Brisbane          Fatal                      No
# 3        2001            Brisbane          Fatal                     Yes
# 4        2001            Brisbane          Fatal                     Yes
#
#   Involving_Driver_Speed Involving_Fatigued_Driver  \
# 0                     No                        No
# 1                     No                        No
# 2                    Yes                        No
# 3                     No                        No
# 4                     No                        No
#
#   Involving_Defective_Vehicle  Count_Crashes  Count_Fatality  \
# 0                          No             25              25
# 1                         Yes              1               1
# ...
